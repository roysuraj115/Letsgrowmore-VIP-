# %%
#importing some basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the data
df=pd.read_csv("global.csv",encoding="latin1")
df.head()
# Out:
# C:\Users\Suraj\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
#perfoming some basic operation on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
#checking for the null value
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#copying the dataframe and renaming the columns
df1=df.copy()
df1.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %% [markdown]
# #plotting graphs to better understand the data

# %%
#plotting Country with the most attacks
plt.figure(figsize=(22,10))
sns.barplot(x=df1.Country.value_counts().head(10).index,y=df1.Country.value_counts().head(10).values)
plt.title("Country with the most attacks")
plt.xlabel("countries")
plt.ylabel("No. of terrorist activities")
# Out:
# Text(0, 0.5, 'No. of terrorist activities')

# %%
#plotting City with the most attacks
plt.figure(figsize=(22,10))
sns.barplot(x=df1.state.value_counts().head(10).index,y=df1.state.value_counts().head(10).values)
plt.title("City with the most attacks")
plt.xlabel("Cities")
plt.ylabel("No. of Attacks/terrorist activities")
# Out:
# Text(0, 0.5, 'No. of Attacks/terrorist activities')

# %%
#plotting Region with the most attacks
plt.figure(figsize=(22,10))
sns.barplot(x=df1.Region.value_counts().head(10).index,y=df1.Region.value_counts().head(10).values)
plt.title("Region with the most attacks")
plt.xlabel("Regions")
plt.ylabel("No. of Attacks/terrorist activities")
# Out:
# Text(0, 0.5, 'No. of Attacks/terrorist activities')

# %%
#plotting Year with the most attacks
plt.figure(figsize=(22,10))
sns.barplot(x=df1.Year.value_counts().index,y=df1.Year.value_counts().values)
plt.title("Year with the most attacks")
plt.xlabel("Year")
plt.ylabel("No. of Attacks/terrorist activities")
# Out:
# Text(0, 0.5, 'No. of Attacks/terrorist activities')

# %%
#plotting Months with the most attacks
plt.figure(figsize=(20,6))
sns.barplot(x=df1.Month.value_counts().index,y=df1.Month.value_counts().values)
plt.title("Month with the most attacks")
plt.xlabel("Month")
plt.ylabel("No. of Attacks/terrorist activities")
# Out:
# Text(0, 0.5, 'No. of Attacks/terrorist activities')

# %%
#plotting Group with most attacks
plt.figure(figsize=(25,10))
sns.barplot(x=df1.Month.value_counts().head(10)[1:].values,y=df1.Group.value_counts().head(10)[1:].index)
plt.title("Group with the most attacks")
plt.xlabel("No. of Attacks/terrorist activities")
plt.ylabel("Group")
# Out:
# Text(0, 0.5, 'Group')

# %%
#plotting Most Attack Types
plt.figure(figsize=(22,10))
sns.barplot(x=df1.AttackType.value_counts().index,y=df1.AttackType.value_counts().values)
plt.title("Most type of attacks")
plt.xlabel("Attack types")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#plotting Most Target Types
plt.figure(figsize=(22,10))
sns.barplot(x=df1.Target_type.value_counts().values,y=df1.Target_type.value_counts().index)
plt.title(" Target with the most attacks")
plt.xlabel("count")
plt.ylabel("Target_type")
# Out:
# Text(0, 0.5, 'Target_type')

# %%
#printing insights
print("Country with the most attacks:",df1['Country'].value_counts().idxmax())
print("City with the most attacks:",df1['city'].value_counts().index[1]) #as first entry is 'unknown'
print("Region with the most attacks:",df1['Region'].value_counts().idxmax())
print("Year with the most attacks:",df1['Year'].value_counts().idxmax())
print("Month with the most attacks:",df1['Month'].value_counts().idxmax())
print("Group with the most attacks:",df1['Group'].value_counts().index[1])
print("Most Attack Types:",df1['AttackType'].value_counts().idxmax())
# Out:
# Country with the most attacks: Iraq
# City with the most attacks: Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %% [markdown]
#                                             Analysis on India

# %%
India=df1[df1.Country=='India']
India.head()
# Out:
#            eventid  Year  Month  Day approxdate  extended resolution  country  \
# 1186  1.972020e+11  1972      2   22        NaN         0        NaN       92
# 2764  1.975010e+11  1975      1    2        NaN         0        NaN       92
# 3857  1.976050e+11  1976      5   26        NaN         0        NaN       92
# 5327  1.977090e+11  1977      9   28        NaN         0        NaN       92
# 7337  1.979010e+11  1979      1   13        NaN         0        NaN       92
#
#      Country  region  ...                                           addnotes  \
# 1186   India       6  ...                                                NaN
# 2764   India       6  ...  The case is very unclear and there are many ru...
# 3857   India       6  ...                                                NaN
# 5327   India       6  ...                                                NaN
# 7337   India       6  ...                                                NaN
#
# ...

# %%
India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11960 entries, 1186 to 181689
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 12.4+ MB

# %%
India.describe()
# Out:
#             eventid          Year         Month           Day      extended  \
# count  1.196000e+04  11960.000000  11960.000000  11960.000000  11960.000000
# mean   2.006313e+11   2006.248411      6.439047     15.624415      0.065385
# std    1.009784e+09     10.096520      3.323835      8.778965      0.247214
# min    1.972020e+11   1972.000000      1.000000      0.000000      0.000000
# 25%    1.999080e+11   1999.000000      4.000000      8.000000      0.000000
# 50%    2.010070e+11   2010.000000      6.000000     15.000000      0.000000
# 75%    2.014110e+11   2014.000000      9.000000     23.000000      0.000000
# max    2.017120e+11   2017.000000     12.000000     31.000000      1.000000
#
#        country   region      latitude     longitude   specificity  ...  \
# count  11960.0  11960.0  11801.000000  11801.000000  11958.000000  ...
# mean      92.0      6.0     25.947957     82.788312      1.576936  ...
# ...

# %%
India.success.value_counts()
# Out:
# 1    10280
# 0     1680
# Name: success, dtype: int64

# %%
India.Year.value_counts().index.sort_values()
# Out:
# Int64Index([1972, 1975, 1976, 1977, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#             1986, 1987, 1988, 1989, 1990, 1991, 1992, 1994, 1995, 1996, 1997,
#             1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#             2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64')

# %%
#plotting attacks in india
plt.figure(figsize=(22,10))
sns.barplot(x=India.Year.value_counts().index,y=India.Year.value_counts().values)
plt.title("Most attacks by Year")
plt.xlabel("Year")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#Month with most attacks
plt.figure(figsize=(22,10))
sns.barplot(x=India.Month.value_counts().index,y=India.Month.value_counts().values)
plt.title("Most attacks by Month")
plt.xlabel("Month")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
#Indian city Targeted the most
plt.figure(figsize=(22,10))
sns.barplot(x=India.city.value_counts().head(10)[2:].index,y=India.city.value_counts().head(10)[2:].values)
plt.title("Most attack in Indian City")
plt.xlabel("Attack types")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#checking target Type in India
plt.figure(figsize=(22,10))
sns.barplot(y=India.Target_type.value_counts().index,x=India.Target_type.value_counts().values)
plt.title("Target Type in India")
plt.xlabel("count")
plt.ylabel("Target Type")
# Out:
# Text(0, 0.5, 'Target Type')

# %%
#plotting groups that mostly attacked India
plt.figure(figsize=(22,10))
sns.barplot(x=India.Group.value_counts().head(11)[1:].values,y=India.Group.value_counts().head(11)[1:].index)
plt.title("Group with most Terror activities")
plt.xlabel("count")
plt.ylabel("Group")
# Out:
# Text(0, 0.5, 'Group')

# %% [markdown]
# SIMILARLY WE CAN DO ANALYSIS AND PLOT FOR OTHER COUNTRIES
