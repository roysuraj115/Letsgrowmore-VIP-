# %% [markdown]
# <a href="https://colab.research.google.com/github/roysuraj115/Letsgrowmore-VIP-/blob/main/day_43.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("suraj")
# Out:
# suraj

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
plt.boxplot(df["median_house_value"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8f66acde50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8f66ad8c50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8f66b15c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8f66a6f750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8f66a6fc90>],
#  'means': []}

# %%
x=df.drop(columns="median_house_value")
y=df["median_house_value"]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=model.predict(xtest)

# %%
pd.DataFrame({"Actual":ytest,"predicted":ypred})
# Out:
#          Actual      predicted
# 4327   191900.0  212611.847091
# 16864   95300.0  166718.273371
# 15993  280000.0  243107.880917
# 3516   163000.0  172202.589371
# 823    218800.0   88151.789760
# ...         ...            ...
# 2397   164800.0  249001.946323
# 5815   193600.0  174305.330863
# 10504   85600.0  -22616.322877
# 12213   97500.0   75295.691701
# 16928   81700.0  127632.988734
#
# [3400 rows x 2 columns]

# %%
model.score(xtest,ytest)
# Out:
# 0.6215931176338747

# %%
sns.pairplot(df,kind="reg")

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
X=df[["housing_median_age","total_rooms","households","median_income"]]
Y=df["median_house_value"]

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.20)

# %%
model2=LinearRegression()

# %%
model2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=model2.predict(x_test)

# %%
model2.score(x_test,y_test)
# Out:
# 0.548423846719349

# %%
sns.lmplot(y _test,ypred)
# Out:
#   File "<ipython-input-41-819ffc8567aa>", line 1
#     sns.lmplot(y _test,ypred)
#                      ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("mobile price.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
sns.countplot(df["price_range"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Target_ratio=df['price_range'].value_counts()/len(df)
print(Target_ratio)
# Out:
# 1    0.25
# 2    0.25
# 3    0.25
# 0    0.25
# Name: price_range, dtype: float64

# %%
plt.bar(Target_ratio.index,Target_ratio)
plt.ylabel('Percentage')
plt.show()

# %%
x=df.drop(columns="price_range")
y=df["price_range"]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()

# %%
model.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
ypred=model.predict(xtest)

# %%
ypred
# Out:
# array([1, 1, 2, 1, 1, 1, 2, 1, 1, 1, 0, 1, 1, 1, 2, 0, 1, 1, 0, 1, 3, 0,
#        3, 3, 2, 2, 2, 1, 0, 0, 2, 3, 0, 0, 3, 0, 0, 0, 1, 1, 1, 2, 3, 2,
#        3, 1, 2, 3, 3, 1, 0, 1, 2, 2, 3, 2, 1, 3, 3, 3, 2, 2, 3, 1, 3, 1,
#        0, 1, 0, 2, 1, 1, 3, 2, 2, 3, 3, 2, 0, 2, 0, 0, 2, 1, 2, 3, 1, 2,
#        0, 0, 3, 3, 0, 2, 0, 3, 2, 0, 1, 3, 0, 2, 3, 3, 0, 2, 0, 0, 2, 0,
#        1, 0, 3, 2, 2, 1, 2, 3, 1, 0, 3, 3, 2, 3, 1, 2, 3, 2, 1, 1, 0, 0,
#        0, 1, 0, 2, 3, 0, 2, 2, 1, 3, 0, 1, 0, 1, 0, 3, 2, 0, 3, 1, 2, 2,
#        3, 2, 2, 0, 3, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 3, 1, 2, 0, 3, 2, 3,
#        2, 1, 3, 2, 1, 1, 0, 0, 3, 2, 1, 2, 1, 2, 2, 0, 2, 3, 0, 2, 0, 0,
#        3, 0, 1, 2, 3, 2, 1, 3, 0, 3, 2, 2, 2, 1, 1, 3, 0, 3, 0, 0, 3, 1,
#        1, 2, 3, 0, 1, 3, 3, 0, 3, 1, 1, 2, 1, 2, 1, 3, 1, 2, 2, 0, 1, 2,
#        2, 2, 0, 3, 3, 2, 3, 3, 1, 2, 1, 2, 3, 2, 0, 2, 0, 1, 1, 3, 3, 0,
#        1, 0, 1, 1, 0, 2, 3, 0, 3, 1, 1, 2, 1, 2, 1, 2, 1, 3, 0, 2, 2, 2,
# ...

# %%
from sklearn.naive_bayes import  BernoulliNB

# %%
model2=BernoulliNB()

# %%
model2.fit(xtrain,ytrain)
# Out:
# BernoulliNB()

# %%
model.score(xtest,ytest)
# Out:
# 0.7975

# %%
model2.score(xtest,ytest)
# Out:
# 0.245

# %%
from sklearn.metrics import accuracy_score

# %%
ypred=model.predict(xtest)
acc_gnb=accuracy_score(ytest,ypred)
print('Accuracy Score: ',acc_gnb)
# Out:
# Accuracy Score:  0.7975

# %%
ypred=model2.predict(xtest)
acc_bnb=accuracy_score(ytest,ypred)
print('Accuracy Score: ',acc_bnb)
# Out:
# Accuracy Score:  0.245

# %%
plt.barh(['Gaussian','Bernoulli'],[acc_gnb,acc_bnb])
# Out:
# <BarContainer object of 2 artists>

# %%
#day 41

# %%
data=pd.read_csv("diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
x=data.drop(columns="Outcome")
y=data["Outcome"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42, stratify=y)

# %%
import sys
print(sys.getsizeof(x_train))
print(sys.getsizeof(x_test))
print(sys.getsizeof(y_train))
print(sys.getsizeof(y_test))
# Out:
# 44240
# 11120
# 9856
# 2496

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#Setup arrays to store training and test accuracies
neighbors = np.arange(1,9)
train_accuracy =np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    #Setup a knn classifier with k neighbors
    knn = KNeighborsClassifier(n_neighbors=k)
    
    #Fit the model
    knn.fit(x_train, y_train)

# %%
#Generate plot
plt.title('k-NN Varying number of neighbors')
plt.plot(neighbors, test_accuracy, label='Testing Accuracy')
plt.plot(neighbors, train_accuracy, label='Training accuracy')
plt.legend()
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy')
plt.show()

# %%
model=KNeighborsClassifier(n_neighbors=2)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
ypred=model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.7272727272727273

# %%
model2=KNeighborsClassifier(n_neighbors=3)

# %%
model2.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
ypred2=model2.predict(x_test)
model2.score(x_test,y_test)
# Out:
# 0.7402597402597403

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
y_pred_proba = model.predict_proba(x_test)[:,1]
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='Knn')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Knn(n_neighbors=2) ROC curve')
plt.show()

# %%
y_pred_proba = model2.predict_proba(x_test)[:,1]
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='Knn')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Knn(n_neighbors=3) ROC curve')
plt.show()

# %%
#day 42

# %%
df=pd.read_csv("/content/Breast_cancer_data.csv")

# %%
df.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.describe()
# Out:
#        mean_radius  mean_texture  mean_perimeter    mean_area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean_smoothness   diagnosis
# count       569.000000  569.000000
# mean          0.096360    0.627417
# std           0.014064    0.483918
# min           0.052630    0.000000
# 25%           0.086370    0.000000
# 50%           0.095870    1.000000
# 75%           0.105300    1.000000
# max           0.163400    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mean_radius      569 non-null    float64
#  1   mean_texture     569 non-null    float64
#  2   mean_perimeter   569 non-null    float64
#  3   mean_area        569 non-null    float64
#  4   mean_smoothness  569 non-null    float64
#  5   diagnosis        569 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 26.8 KB

# %%
df.isnull().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
Features=df.drop(columns="diagnosis",axis=1)
Target=df["diagnosis"]

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap="Blues")

# %%
Target_ratio=df["diagnosis"].value_counts()/len(df)
print(Target_ratio)
# Out:
# 1    0.627417
# 0    0.372583
# Name: diagnosis, dtype: float64

# %%
sns.barplot(Target_ratio.index,Target_ratio)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
xtrain,xtest,ytrain,ytest=train_test_split(Features,Target,test_size=0.2)

# %%
print("After Splitting the data-")
print("Size of the input train data is:",sys.getsizeof(xtrain))
print("Size of the input test data is:",sys.getsizeof(xtest))
print("Size of the oputput train data is:",sys.getsizeof(ytrain))
print("Size of the output test data is:",sys.getsizeof(ytest))
# Out:
# After Splitting the data-
# Size of the input train data is: 21872
# Size of the input test data is: 5504
# Size of the oputput train data is: 7312
# Size of the output test data is: 1856

# %%
from sklearn.svm import SVC

# %%
model=SVC(C=10,kernel='linear')

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC(C=10, kernel='linear')

# %%
ypred=model.predict(xtest)

# %%
model.score(xtest,ytest)
# Out:
# 0.9035087719298246

# %%
from sklearn.metrics import accuracy_score

# %%
print("Accuracy Score of Linear Model:",accuracy_score(ypred,ytest))
# Out:
# Accuracy Score of Linear Model: 0.9035087719298246

# %%
model2=SVC(C=10,kernel='rbf',gamma=2)

# %%
model2.fit(xtrain,ytrain)
# Out:
# SVC(C=10, gamma=2)

# %%
ypred2=model.predict(xtest)

# %%
print("Accuracy Score of Gaussian Model:",accuracy_score(ypred2,ytest))
# Out:
# Accuracy Score of Gaussian Model: 0.9035087719298246

# %%
#Day 43

# %%
#day 44
